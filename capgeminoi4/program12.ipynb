# %%
import pandas as pd
df=pd.read_csv('customers-100.csv')
print(df.head())
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
json_data=df.to_json(orient='records',indent=4)
print(json_data)
# Out:
# [
#     {
#         "Index":1,
#         "Customer Id":"DD37Cf93aecA6Dc",
#         "First Name":"Sheryl",
#         "Last Name":"Baxter",
#         "Company":"Rasmussen Group",
#         "City":"East Leonard",
#         "Country":"Chile",
#         "Phone 1":"229.077.5154",
#         "Phone 2":"397.884.0519x718",
#         "Email":"zunigavanessa@smith.info",
#         "Subscription Date":"2020-08-24",
#         "Website":"http:\/\/www.stephenson.com\/"
#     },
#     {
#         "Index":2,
#         "Customer Id":"1Ef7b82A4CAAD10",
#         "First Name":"Preston",
#         "Last Name":"Lozano",
#         "Company":"Vega-Gentry",
#         "City":"East Jimmychester",
#         "Country":"Djibouti",
#         "Phone 1":"5153435776",
#         "Phone 2":"686-620-1820x944",
#         "Email":"vmata@colon.com",
#         "Subscription Date":"2021-04-23",
#         "Website":"http:\/\/www.hobbs.com\/"
#     },
#     {
#         "Index":3,
#         "Customer Id":"6F94879bDAfE5a6",
# ...

# %%
html=df.to_html()
with open('df.html', 'w') as f:
    f.write(df.to_html())

# %%
df[df['City']=='East Jimmychester']
# Out:
#    Index      Customer Id First Name Last Name      Company  \
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano  Vega-Gentry
#
#                 City   Country     Phone 1           Phone 2            Email  \
# 1  East Jimmychester  Djibouti  5153435776  686-620-1820x944  vmata@colon.com
#
#   Subscription Date                Website
# 1        2021-04-23  http://www.hobbs.com/

# %%
df.sort_values(by="First Name")
# Out:
#     Index      Customer Id  First Name Last Name                   Company  \
# 5       6  2d08FB17EE273F4       Aimee     Downs              Steele Group
# 79     80  A7F85c1DE4dB87f   Alejandro     Blair  Combs, Waller and Durham
# 70     71  CBCd2Ac8E3eBDF9  Alexandria      Buck             Keller-Coffey
# 87     88  E4Bbcd8AD81fC5f      Alison    Vargas   Vaughn, Watts and Leach
# 73     74  A3F76Be153Df4a3       Anita    Benson               Parrish Ltd
# ..    ...              ...         ...       ...                       ...
# 12     13  e35426EbDEceaFF      Tracey      Mata            Graham-Francis
# 88     89  efeb73245CDf1fF      Vernon      Kane         Carter-Strickland
# 68     69  421a109cABDf5fa    Virginia    Dudley                Warren Ltd
# 42     43  7E441b6B228DBcA       Wayne   Simpson           Perkins-Trevino
# 98     99  c23d1D9EE8DEB0A      Yvonne    Farmer        Fitzgerald-Harrell
#
# ...

# %%
df.groupby('City').size()
# Out:
# City
# Acevedoville        1
# Bensonview          1
# Brittanyview        1
# Bryanville          1
# Burchbury           1
#                    ..
# West Marthaburgh    1
# West Priscilla      1
# West Reginald       1
# West Samuel         1
# Zimmermanland       1
# Length: 100, dtype: int64

# %%
df.groupby('Customer Id').size()
# Out:
# Customer Id
# 010468dAA11382c    1
# 03A1E62ADdeb31c    1
# 053d585Ab6b3159    1
# 09D7D7C8Fe09aea    1
# 0F60FF3DdCd7aB0    1
#                   ..
# efeb73245CDf1fF    1
# f3BEf3Be028166f    1
# fD780ED8dbEae7B    1
# fF1b6c9E8Fbf1ff    1
# faCEF517ae7D8eB    1
# Length: 100, dtype: int64

# %%
import pandas as pd

data="""Index,Name,Age,City
2,Alice,25,New York
1,Bob,30,San Francisco
4,Charlie,22,Chicago
3,David,28,Los Angeles
"""
with open("output.csv","w") as file:
     file.write(data)
df=pd.read_csv('output.csv')
df.set_index(['Age'],inplace=True)
print(df)
# Out:
#      Index     Name           City
# Age
# 25       2    Alice       New York
# 30       1      Bob  San Francisco
# 22       4  Charlie        Chicago
# 28       3    David    Los Angeles

# %%
import pandas as pd

data = {
    'Region': ['North', 'North', 'South', 'South', 'East', 'East'],
    'State': ['Delhi', 'Punjab', 'Tamil Nadu', 'Karnataka', 'TG', 'Odisha'],
    'Year': [2021, 2022, 2021, 2022, 2021, 2022],
    'Sales': [750000, 820000, 690000, 720000, 670000, 710000],
    'Profit': [95000, 102000, 85000, 91000, 77000, 88000]
}
df=pd.DataFrame(data)
print(df)
df.set_index(['Region','State','Year'],inplace=True)
print(df)
df1=df.loc[('South','Tamil Nadu',2021),'Sales']
print(df1)
# Out:
#   Region       State  Year   Sales  Profit
# 0  North       Delhi  2021  750000   95000
# 1  North      Punjab  2022  820000  102000
# 2  South  Tamil Nadu  2021  690000   85000
# 3  South   Karnataka  2022  720000   91000
# 4   East          TG  2021  670000   77000
# 5   East      Odisha  2022  710000   88000
#                          Sales  Profit
# Region State      Year
# North  Delhi      2021  750000   95000
#        Punjab     2022  820000  102000
# South  Tamil Nadu 2021  690000   85000
#        Karnataka  2022  720000   91000
# East   TG         2021  670000   77000
#        Odisha     2022  710000   88000
# 690000

# %%
import pandas as pd

data = {
    'Region': ['North', 'North', 'South', 'South', 'East', 'East'],
    'State': ['Delhi', 'Punjab', 'Tamil Nadu', 'Karnataka', 'TG', 'Odisha'],
    'Year': [2021, 2022, 2021, 2022, 2021, 2022],
    'Sales': [750000, 820000, 690000, 720000, 670000, 710000],
    'Profit': [95000, 102000, 85000, 91000, 77000, 88000]
}
df=pd.DataFrame(data)
data2 = {
    'Region': ['North', 'South', 'East', 'West'],
    'State': ['Delhi', 'Tamil Nadu', 'TG', 'Goa'],
    'Year': [2021, 2021, 2021, 2023],
    'Discount':[5,7, 10, 6],
    'Customer_Count':[500, 600, 450, 300]
}
df2 = pd.DataFrame(data2)
merge_inner=pd.merge(df,df2,on=['Region','State','Year'],how='inner')
print(merge_inner)
merge_inner1=pd.merge(df,df2,on=['Region','State','Year'],how='left')
print(merge_inner1)
# Out:
#   Region       State  Year   Sales  Profit  Discount  Customer_Count
# 0  North       Delhi  2021  750000   95000         5             500
# 1  South  Tamil Nadu  2021  690000   85000         7             600
# 2   East          TG  2021  670000   77000        10             450
#   Region       State  Year   Sales  Profit  Discount  Customer_Count
# 0  North       Delhi  2021  750000   95000       5.0           500.0
# 1  North      Punjab  2022  820000  102000       NaN             NaN
# 2  South  Tamil Nadu  2021  690000   85000       7.0           600.0
# 3  South   Karnataka  2022  720000   91000       NaN             NaN
# 4   East          TG  2021  670000   77000      10.0           450.0
# 5   East      Odisha  2022  710000   88000       NaN             NaN
